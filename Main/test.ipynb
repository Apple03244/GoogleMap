# %%
from GooglemapCraw_v2 import GooglemapCraw
from NotionUpload import Notion
from UserBaseRev import UserBaseRev
# Out:
# /Users/ijeonghun/Documents/github/GoogleMap/googlemap/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### 첫번째 스텝
#
# 음식점 리스트 +  유저 URL Search

# %%
First_craw=GooglemapCraw("강남맛집",restaurant_num=100,review_num=100,thread_num=1,optional=False)
First_craw.craw_ras()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]Exception in thread Thread-71:
# Traceback (most recent call last):
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/Users/ijeonghun/Documents/github/GoogleMap/googlemap/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ijeonghun/Documents/github/GoogleMap/Main/GooglemapCraw_v2.py", line 46, in __crawras
#     rating=float(rating)
# ValueError: could not convert string to float: ''
# 100%|██████████| 1/1 [00:25<00:00, 25.04s/it]

# %%
First_craw.main_drive.quit()

# %%
First_craw.infos
# Out:
# [{'search_term': '강남맛집',
#   'restaurant_name': '바비레드 강남본점',
#   'url': 'https://www.google.co.kr/maps/place/%EB%B0%94%EB%B9%84%EB%A0%88%EB%93%9C+%EA%B0%95%EB%82%A8%EB%B3%B8%EC%A0%90/data=!4m7!3m6!1s0x357ca3e29805ba2f:0x339ec75093d60a3b!8m2!3d37.5026295!4d127.0278967!16s%2Fg%2F11bbtlp9qn!19sChIJL7oFmOKjfDUROwrWk1DHnjM?authuser=0&hl=ko&rclk=1',
#   'address': '주소: 서울특별시 강남구 봉은사로6길 39, 지하 바비레드',
#   'rating': 4.3,
#   'category': '퓨전 음식점'},
#  {'search_term': '강남맛집',
#   'restaurant_name': '구구당',
#   'url': 'https://www.google.co.kr/maps/place/%EA%B5%AC%EA%B5%AC%EB%8B%B9/data=!4m7!3m6!1s0x357ca318c534fbe7:0x907ab2785197b7ff!8m2!3d37.5032812!4d127.0278706!16s%2Fg%2F11h7r1wcsz!19sChIJ5_s0xRijfDUR_7eXUXiyepA?authuser=0&hl=ko&rclk=1',
#   'address': '주소: 서울특별시 강남구 강남대로102길 35',
#   'rating': 4.1,
#   'category': '퓨전 음식점'},
#  {'search_term': '강남맛집',
#   'restaurant_name': '강남 원주추어탕',
# ...

# %%
import importlib
import Base
import Restaurant
from selenium.webdriver.support.expected_conditions import presence_of_all_elements_located
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By

# %%
importlib.reload(Base)
importlib.reload(Restaurant)
# Out:
# <module 'Restaurant' from '/Users/ijeonghun/Documents/github/GoogleMap/Main/Restaurant.py'>

# %%
test_driver=Base.GetDrive(Optional=True)

# %%
url=Restaurant.ParsingURL("강남맛집")
test_driver.get(url)

# %%
body=Base.GetElement(test_driver,'//*[@role="feed"]')
@Base.ScrollDown(body,100)
def get_subbox(element):
    subboxs=Base.GetElements(element,"//a[@href and @aria-label]")
    return [Restaurant.get_Name_URL(sub) for sub in subboxs]
get_subbox(body)
# Out:
# [{'Name': '바비레드 강남본점',
#   'URL': 'https://www.google.co.kr/maps/place/%EB%B0%94%EB%B9%84%EB%A0%88%EB%93%9C+%EA%B0%95%EB%82%A8%EB%B3%B8%EC%A0%90/data=!4m7!3m6!1s0x357ca3e29805ba2f:0x339ec75093d60a3b!8m2!3d37.5026295!4d127.0278967!16s%2Fg%2F11bbtlp9qn!19sChIJL7oFmOKjfDUROwrWk1DHnjM?authuser=0&hl=ko&rclk=1'},
#  {'Name': '정돈 강남점',
#   'URL': 'https://www.google.co.kr/maps/place/%EC%A0%95%EB%8F%88+%EA%B0%95%EB%82%A8%EC%A0%90/data=!4m7!3m6!1s0x357ca39dc0941e5f:0x73d7fe7d16782344!8m2!3d37.5039525!4d127.026436!16s%2Fg%2F11gxs6965c!19sChIJXx6UwJ2jfDURRCN4Fn3-13M?authuser=0&hl=ko&rclk=1'},
#  {'Name': '다몽집 신논현본점',
#   'URL': 'https://www.google.co.kr/maps/place/%EB%8B%A4%EB%AA%BD%EC%A7%91+%EC%8B%A0%EB%85%BC%ED%98%84%EB%B3%B8%EC%A0%90/data=!4m7!3m6!1s0x357ca1fe8a7c65df:0x61794fad3b2343f9!8m2!3d37.5017757!4d127.0271357!16s%2Fg%2F11mqxb0p55!19sChIJ32V8iv6hfDUR-UMjO61PeWE?authuser=0&hl=ko&rclk=1'},
#  {'Name': '단골손님 강남1호점',
# ...

# %%
test_elements=Base.GetElements(drive=test_driver,condition='//*[@role="feed"]',time_out=1)

# %%
test_elements
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="90b7e9c764dd1964b83d0bb129f3e367", element="f.0977411A79D2F31E3FE2DE6BF2026205.d.C890F8DA76138FD7F6241F95C526792A.e.187")>]

# %%
test_driver.quit()

# %%
test_func=ContentCrawBase.GetElements(test_driver,presence_of_all_elements_located,1)

# %%
test_func(condition="//*[contains(text(),'asldjnalskndlak')]")

# %%
bool(None)
# Out:
# False
